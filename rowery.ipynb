# %%
import numpy as no
import pandas as pd

# %%
ds = pd.read_csv('/content/JC-202603-citibike-tripdata.csv')
ds.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  9AFD73B0B5FF8748  electric_bike  2026-03-06 15:35:01.876
# 1  D0CBF2632ADAA85B  electric_bike  2026-03-06 20:38:36.431
# 2  86A08062BB25F35D  electric_bike  2026-03-20 17:28:48.029
# 3  68F8E70321348B5B   classic_bike  2026-03-04 14:34:57.979
# 4  4ABA929EBE8489E2  electric_bike  2026-03-23 09:33:33.798
#
#                   ended_at            start_station_name start_station_id  \
# 0  2026-03-06 16:29:08.419       Bergen Ave & Stegman St            JC108
# 1  2026-03-06 20:52:09.557       Danforth Ave & JFK Blvd            JC144
# 2  2026-03-20 17:46:03.522       Danforth Ave & JFK Blvd            JC144
# 3  2026-03-04 14:38:44.106    Danforth Ave & Sullivan Dr            JC135
# 4  2026-03-23 09:38:12.202  West Side Ave & Stegman Pkwy            JC131
#
#           end_station_name end_station_id  start_lat  start_lng   end_lat  \
# 0  Danforth Ave & JFK Blvd          JC144  40.706575 -74.086701  40.70056
# ...

# %%
print(ds.columns)

cols = ['ride_id', 'rideable_type', 'started_at', 'ended_at',
       'start_station_name', 'end_station_name']
ds[cols]

ds['started_at'] = pd.to_datetime(ds['started_at'])
ds['ended_at'] = pd.to_datetime(ds['ended_at'])

ds['time'] = ds['ended_at'] - ds['started_at']
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')
